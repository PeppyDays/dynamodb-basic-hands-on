# %% [markdown]
# # Working with Streams
#
# DynamoDB Streams captures a time-ordered sequence of item-level modifications in any DynamoDB table and stores this information in a log for up to 24 hours. Applications can access this log and view the data items as they appeared before and after they were modified, in near-real time.
#
# The common usage is using lambda functions which are triggered by DynamoDB Streams and do further jobs in Lambda for various reasons.
#
# Here, we will use DynamoDB Streams for game leader board to rank players in score order. Two tables will be created, one for user scoring history and the other for user total score. Threre are two known query patterns as follows.
#
# - Show the user's scoring history up to 100 latest items
# - Show the top 3 players who have the highest scores
#
# We will use DynamoDB Streams and Lambda to update user's total score in near-real time.
#
# The two tables are described here.
#
# | Table/Index | Key/Attribute | Description | Sample |
# | -- | -- | -- | -- |
# | UserScoreEvents (Table) | UserId (PK) | User ID | harris, donald |
# | | Timestamp (SK) | Timestamp when getting score | 2020-09-16 00:59:07.420452 |
# | | Score (Attr) | Score the user gets | Any integer value between 0 and 9 |
#
# | Table/Index | Key/Attribute | Description | Sample |
# | -- | -- | -- | -- |
# | Leaderboard (Table) | UserId (PK) | User ID | harris, donald |
# | | Score (Attr) | Total score the user has gained | 58, 92 |
# | | ShardNo (Attr) | For writing sharding | Any integer value between 0 and 9 |
# | IndexScore (Index) | ShardNo (PK) | | |
# | | Score (SK) | | |
#
# > For write sharding, please see [this blog](https://aws.amazon.com/blogs/database/choosing-the-right-number-of-shards-for-your-large-scale-amazon-dynamodb-table/). This will be covered in DynamoDB Modeling session.
#
# Firstly, let's create two tables and enable DynamoDB Streams for the source table `UserScoreEvents`.

# %%
# import and get dynamodb resource
import boto3
from boto3.dynamodb.conditions import Key, Attr
from botocore.exceptions import ClientError
from pprint import pprint, pformat
from decimal import Decimal
import time
import multiprocessing as mp
import csv
from datetime import datetime
import random
from collections import defaultdict
import heapq


dynamodb = boto3.resource('dynamodb')

# %%
# create UserScoreEvents table with DynamoDB Streams
user_score_events = dynamodb.create_table(
    TableName='UserScoreEvents',
    AttributeDefinitions=[
        {'AttributeName': 'UserId', 'AttributeType': 'S'},
        {'AttributeName': 'Timestamp', 'AttributeType': 'S'}
    ],
    KeySchema=[
        {'AttributeName': 'UserId', 'KeyType': 'HASH'},
        {'AttributeName': 'Timestamp', 'KeyType': 'RANGE'}
    ],
    BillingMode='PAY_PER_REQUEST',
    StreamSpecification={
        'StreamEnabled': True,
        'StreamViewType': 'NEW_IMAGE'
    }
)

user_score_events.wait_until_exists()

# %%
# create Leaderboard table and this is the target table of DynamoDB Streams
leaderboard = dynamodb.create_table(
    TableName='Leaderboard',
    AttributeDefinitions=[
        {'AttributeName': 'UserId', 'AttributeType': 'S'},
        {'AttributeName': 'Score', 'AttributeType': 'N'},
        {'AttributeName': 'ShardNo', 'AttributeType': 'N'},
    ],
    KeySchema=[
        {'AttributeName': 'UserId', 'KeyType': 'HASH'}
    ],
    GlobalSecondaryIndexes=[
        {
            'IndexName': 'IndexShardNoScore',
            'KeySchema': [
                {'AttributeName': 'ShardNo', 'KeyType': 'HASH'},
                {'AttributeName': 'Score', 'KeyType': 'RANGE'}
            ],
            'Projection': {
                'ProjectionType': 'ALL'
            }
        }
    ],
    BillingMode='PAY_PER_REQUEST'
)

leaderboard.wait_until_exists()

# %% [markdown]
# After that, we should create a Lambda function that is triggered by new items in the source table and update the user's total score in the target table. It has two steps.
#
# - Create IAM role for Lambda
#     - Role name: DynamoDBStreamReplicationExample
#     - Included policies: AmazonDynamoDBFullAccess, CloudWatchLogsFullAccess
# - Create Lambda function
#     - Lambda function name: UpdateUserTotalScore
#     - Runtime: Python 3.8
#     - Role: DynamoDBStreamReplicationExample
#
# After creating the Lambda function, we should make a trigger in the source table to invoke the Lambda function whenever new items are added. Go to DynamoDB service console and choose `UserScoreEvents` table. In `Triggers` tab, you can create a trigger and set the Lambda function.
#
# Originally, lambda can be invoked only when someone call it. DynamoDB Streams stored all mutations of the base table, but doesn't call Lambda. Trigger bonds between Streams and Lambda, that invokes the given Lambda function whenever Streams gets a new record.
#
# To see how events information is transferred to Lambda function, let's fill the code line of Lambda function as follows.
#
# ```python
# import boto3
#
#
# def lambda_handler(event, context):
#     print(event)
# ```
#
# After that, put one item in the `UserScoreEvents` table with the following command.

# %%
user_score_events.put_item(
    Item={
        'UserId': 'dongkyun',
        'Timestamp': str(datetime.now()),
        'Score': 1
    }
)
# Out:
# {'ResponseMetadata': {'RequestId': '9EDLMDSNVIKD4VBSV03E1I3SQ3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 06 Oct 2020 16:21:23 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '9EDLMDSNVIKD4VBSV03E1I3SQ3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %% [markdown]
# After that, check the Lambda execution log in CloudWatch. Here is the event value the Lambda takes.
#
# ```json
# {
#   "Records": [
#     {
#       "eventID": "1caffc48a12f1d1fbfa1ac33f027db95",
#       "eventName": "INSERT",
#       "eventVersion": "1.1",
#       "eventSource": "aws:dynamodb",
#       "awsRegion": "ap-northeast-2",
#       "dynamodb": {
#         "ApproximateCreationDateTime": 1600238837.0,
#         "Keys": {
#           "UserId": {
#             "S": "dongkyun"
#           },
#           "Timestamp": {
#             "S": "2020-09-16 06:47:17.079179"
#           }
#         },
#         "NewImage": {
#           "Score": {
#             "N": "1"
#           },
#           "UserId": {
#             "S": "dongkyun"
#           },
#           "Timestamp": {
#             "S": "2020-09-16 06:47:17.079179"
#           }
#         },
#         "SequenceNumber": "300000000014403348924",
#         "SizeBytes": 105,
#         "StreamViewType": "NEW_IMAGE"
#       },
#       "eventSourceARN": "arn:aws:dynamodb:ap-northeast-2:886100642687:table/UserScoreEvents/stream/2020-09-16T06:24:46.998"
#     }
#   ]
# }
# ```
#
# Now it's clear what we should do. From the event value, we should parse `UserId` and `Score` values. With the values, we should update `Leaderboard` table by adding the given score. So, the Lambda function code will look like this.
#
# ```python
# import boto3
#
#
# def lambda_handler(event, context):
#     leaderboard = boto3.resource('dynamodb').Table('Leaderboard')
#
#     for record in event['Records']:
#         if 'NewImage' in record['dynamodb']:
#             item = record['dynamodb']['NewImage']
#             user_id = item['UserId']['S']
#             shard_no = hash(user_id) % 10
#             score = int(item['Score']['N'])
#
#             leaderboard.update_item(
#                 Key={'UserId': user_id},
#                 UpdateExpression='ADD Score :score SET ShardNo = :shard_no',
#                 ExpressionAttributeValues={
#                     ':score': score,
#                     ':shard_no': shard_no
#                 }
#             )
# ```
#
# We're all done! Test with some sample inputs to see if it works well.

# %%
user_score_events.put_item(
    Item={
        'UserId': 'reed',
        'Timestamp': str(datetime.now()),
        'Score': 2
    }
)

user_score_events.put_item(
    Item={
        'UserId': 'reed',
        'Timestamp': str(datetime.now()),
        'Score': 5
    }
)

user_score_events.put_item(
    Item={
        'UserId': 'wesley',
        'Timestamp': str(datetime.now()),
        'Score': 8
    }
)
# Out:
# {'ResponseMetadata': {'RequestId': 'R6QG9J7D14DALG79B7VG9FO9BJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 06 Oct 2020 16:24:48 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'R6QG9J7D14DALG79B7VG9FO9BJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
user_score_events.scan()
# Out:
# {'Items': [{'Score': Decimal('8'),
#    'UserId': 'wesley',
#    'Timestamp': '2020-10-06 16:24:48.573743'},
#   {'Score': Decimal('2'),
#    'UserId': 'reed',
#    'Timestamp': '2020-10-06 16:24:48.557943'},
#   {'Score': Decimal('5'),
#    'UserId': 'reed',
#    'Timestamp': '2020-10-06 16:24:48.566050'}],
#  'Count': 3,
#  'ScannedCount': 3,
#  'ResponseMetadata': {'RequestId': '821HACE3GQ5EEPC5NR853G7IHRVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 06 Oct 2020 16:24:50 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '307',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '821HACE3GQ5EEPC5NR853G7IHRVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2257209555'},
#   'RetryAttempts': 0}}

# %%
leaderboard.scan()
# Out:
# {'Items': [{'Score': Decimal('8'),
#    'ShardNo': Decimal('4'),
#    'UserId': 'wesley'},
#   {'Score': Decimal('7'), 'ShardNo': Decimal('6'), 'UserId': 'reed'}],
#  'Count': 2,
#  'ScannedCount': 2,
#  'ResponseMetadata': {'RequestId': 'FI5PHBHC5V5VI2S8POQQBK3Q8FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 06 Oct 2020 16:24:51 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '164',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'FI5PHBHC5V5VI2S8POQQBK3Q8FVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '3076067450'},
#   'RetryAttempts': 0}}

# %% [markdown]
# It is perfectly working with the sample data. Let's clean up the table and simulate the real case.

# %%
# delete all items in the table
user_score_events.delete_item(
    Key={'UserId': 'wesley', 'Timestamp': '2020-09-16 00:59:07.428408'}
)
user_score_events.delete_item(
    Key={'UserId': 'reed', 'Timestamp': '2020-09-16 00:59:07.377314'}
)
user_score_events.delete_item(
    Key={'UserId': 'reed', 'Timestamp': '2020-09-16 00:59:07.420452'}
)
leaderboard.delete_item(
    Key={'UserId': 'reed'}
)
leaderboard.delete_item(
    Key={'UserId': 'wesley'}
)
# Out:
# {'ResponseMetadata': {'RequestId': 'H8PS7KM9ND499B0VF08UPHMDMJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Tue, 06 Oct 2020 16:25:55 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'H8PS7KM9ND499B0VF08UPHMDMJVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
# prepare functions to simulate a game user
def simulate_user(user_id, duration=10, max_score=10):
    finish_time = time.time() + duration
    items = []

    while time.time() <= finish_time:
        timestamp = str(datetime.now())
        score = random.randrange(max_score)

        item = {'UserId': user_id, 'Timestamp': timestamp, 'Score': score}
        items.append(item)

        print('{}: User [{:^10}] gets {} score'.format(timestamp, user_id, score))

        user_score_events.put_item(Item=item)
        time.sleep(random.uniform(0, 5))

    return {user_id: items}

user_scores = {}

def gather_user_scores(result):
    global user_scores

    user_scores.update(result)

# %%
# it will put user dongkyun's game score for 10 seconds with random gap
simulate_user('dongkyun', 10, 10)
# Out:
# 2020-10-06 16:27:08.959560: User [ dongkyun ] gets 6 score
# 2020-10-06 16:27:13.851667: User [ dongkyun ] gets 2 score
# 2020-10-06 16:27:14.108918: User [ dongkyun ] gets 8 score
# 2020-10-06 16:27:14.729089: User [ dongkyun ] gets 8 score
# 2020-10-06 16:27:17.352352: User [ dongkyun ] gets 7 score
# {'dongkyun': [{'UserId': 'dongkyun',
#    'Timestamp': '2020-10-06 16:27:08.959560',
#    'Score': 6},
#   {'UserId': 'dongkyun',
#    'Timestamp': '2020-10-06 16:27:13.851667',
#    'Score': 2},
#   {'UserId': 'dongkyun',
#    'Timestamp': '2020-10-06 16:27:14.108918',
#    'Score': 8},
#   {'UserId': 'dongkyun',
#    'Timestamp': '2020-10-06 16:27:14.729089',
#    'Score': 8},
#   {'UserId': 'dongkyun',
#    'Timestamp': '2020-10-06 16:27:17.352352',
#    'Score': 7}]}

# %%
# with 10 game users, let's see the architecture we built runs well
user_ids = ['marah', 'teegan', 'quynn', 'kuame', 'reed', 'alyssa', 'wesley', 'mariam', 'macaulay', 'maggy']
user_scores = {}

test_duration_in_seconds = 60

with mp.Pool(processes=len(user_ids)) as pool:
    for user_id in user_ids:
        pool.apply_async(simulate_user, (user_id, test_duration_in_seconds), callback=gather_user_scores)
    
    pool.close()
    pool.join()
# Out:
# 2020-10-06 16:29:04.682309: User [  marah   ] gets 4 score
# 2020-10-06 16:29:04.682641: User [  quynn   ] gets 7 score
# 2020-10-06 16:29:04.683098: User [  alyssa  ] gets 7 score
# 2020-10-06 16:29:04.682957: User [   reed   ] gets 0 score
# 2020-10-06 16:29:04.683232: User [  wesley  ] gets 5 score
# 2020-10-06 16:29:04.683370: User [  mariam  ] gets 2 score
# 2020-10-06 16:29:04.682793: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:04.682461: User [  teegan  ] gets 4 score
# 2020-10-06 16:29:04.684618: User [ macaulay ] gets 9 score
# 2020-10-06 16:29:04.684688: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:04.822050: User [  marah   ] gets 1 score
# 2020-10-06 16:29:05.114522: User [  quynn   ] gets 4 score
# 2020-10-06 16:29:05.521620: User [  mariam  ] gets 1 score
# 2020-10-06 16:29:05.759091: User [  maggy   ] gets 0 score
# 2020-10-06 16:29:06.554023: User [  maggy   ] gets 4 score
# 2020-10-06 16:29:07.333354: User [  quynn   ] gets 0 score
# 2020-10-06 16:29:07.767107: User [  teegan  ] gets 7 score
# 2020-10-06 16:29:07.849070: User [ macaulay ] gets 2 score
# 2020-10-06 16:29:08.115437: User [  marah   ] gets 1 score
# 2020-10-06 16:29:08.190986: User [  mariam  ] gets 0 score
# 2020-10-06 16:29:08.478811: User [  maggy   ] gets 0 score
# 2020-10-06 16:29:08.620074: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:08.657065: User [  wesley  ] gets 1 score
# 2020-10-06 16:29:09.221575: User [   reed   ] gets 1 score
# 2020-10-06 16:29:09.725104: User [  alyssa  ] gets 0 score
# 2020-10-06 16:29:09.744649: User [  maggy   ] gets 5 score
# 2020-10-06 16:29:10.506932: User [  kuame   ] gets 5 score
# 2020-10-06 16:29:10.534052: User [  alyssa  ] gets 7 score
# 2020-10-06 16:29:10.714070: User [   reed   ] gets 2 score
# 2020-10-06 16:29:10.774727: User [  mariam  ] gets 0 score
# 2020-10-06 16:29:10.990997: User [  quynn   ] gets 7 score
# 2020-10-06 16:29:11.191056: User [  mariam  ] gets 0 score
# 2020-10-06 16:29:11.265707: User [  kuame   ] gets 0 score
# 2020-10-06 16:29:11.421110: User [  mariam  ] gets 5 score
# 2020-10-06 16:29:11.592072: User [ macaulay ] gets 7 score
# 2020-10-06 16:29:11.701163: User [  teegan  ] gets 2 score
# 2020-10-06 16:29:11.797909: User [  kuame   ] gets 3 score
# 2020-10-06 16:29:11.928996: User [  teegan  ] gets 0 score
# 2020-10-06 16:29:12.072282: User [  maggy   ] gets 4 score
# 2020-10-06 16:29:12.477066: User [  quynn   ] gets 0 score
# 2020-10-06 16:29:12.517666: User [  quynn   ] gets 1 score
# 2020-10-06 16:29:12.529032: User [  alyssa  ] gets 3 score
# 2020-10-06 16:29:12.599371: User [  marah   ] gets 9 score
# 2020-10-06 16:29:12.690846: User [  alyssa  ] gets 1 score
# 2020-10-06 16:29:12.719405: User [  alyssa  ] gets 4 score
# 2020-10-06 16:29:12.869082: User [  wesley  ] gets 2 score
# 2020-10-06 16:29:12.958887: User [  teegan  ] gets 3 score
# 2020-10-06 16:29:13.301246: User [  quynn   ] gets 7 score
# 2020-10-06 16:29:13.641572: User [  maggy   ] gets 7 score
# 2020-10-06 16:29:13.812164: User [  maggy   ] gets 9 score
# 2020-10-06 16:29:14.000731: User [  teegan  ] gets 9 score
# 2020-10-06 16:29:14.145393: User [   reed   ] gets 9 score
# 2020-10-06 16:29:14.196844: User [  quynn   ] gets 0 score
# 2020-10-06 16:29:14.726544: User [   reed   ] gets 3 score
# 2020-10-06 16:29:14.802038: User [  alyssa  ] gets 3 score
# 2020-10-06 16:29:14.937068: User [  mariam  ] gets 6 score
# 2020-10-06 16:29:15.306168: User [  mariam  ] gets 0 score
# 2020-10-06 16:29:15.460351: User [  marah   ] gets 7 score
# 2020-10-06 16:29:15.522159: User [ macaulay ] gets 4 score
# 2020-10-06 16:29:15.905898: User [  maggy   ] gets 4 score
# 2020-10-06 16:29:15.909068: User [  wesley  ] gets 2 score
# 2020-10-06 16:29:15.982829: User [  wesley  ] gets 7 score
# 2020-10-06 16:29:16.385375: User [  kuame   ] gets 3 score
# 2020-10-06 16:29:16.453050: User [  marah   ] gets 9 score
# 2020-10-06 16:29:16.817869: User [  quynn   ] gets 6 score
# 2020-10-06 16:29:17.534278: User [  wesley  ] gets 4 score
# 2020-10-06 16:29:17.650349: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:17.997854: User [  mariam  ] gets 7 score
# 2020-10-06 16:29:18.041751: User [  wesley  ] gets 9 score
# 2020-10-06 16:29:18.382646: User [  alyssa  ] gets 4 score
# 2020-10-06 16:29:18.562883: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:18.769049: User [  teegan  ] gets 4 score
# 2020-10-06 16:29:18.891486: User [   reed   ] gets 6 score
# 2020-10-06 16:29:19.079579: User [  mariam  ] gets 3 score
# 2020-10-06 16:29:19.447290: User [  quynn   ] gets 1 score
# 2020-10-06 16:29:19.613064: User [  maggy   ] gets 6 score
# 2020-10-06 16:29:20.349088: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:20.746542: User [  kuame   ] gets 9 score
# 2020-10-06 16:29:20.885502: User [  marah   ] gets 4 score
# 2020-10-06 16:29:20.922485: User [   reed   ] gets 1 score
# 2020-10-06 16:29:21.966639: User [  quynn   ] gets 8 score
# 2020-10-06 16:29:22.089387: User [  teegan  ] gets 0 score
# 2020-10-06 16:29:22.213452: User [  alyssa  ] gets 0 score
# 2020-10-06 16:29:22.568246: User [  wesley  ] gets 3 score
# 2020-10-06 16:29:22.687131: User [ macaulay ] gets 7 score
# 2020-10-06 16:29:23.161219: User [  mariam  ] gets 4 score
# 2020-10-06 16:29:23.257922: User [  kuame   ] gets 2 score
# 2020-10-06 16:29:23.436164: User [   reed   ] gets 6 score
# 2020-10-06 16:29:23.679077: User [  marah   ] gets 8 score
# 2020-10-06 16:29:24.129999: User [  maggy   ] gets 7 score
# 2020-10-06 16:29:24.492517: User [  mariam  ] gets 8 score
# 2020-10-06 16:29:24.558122: User [  wesley  ] gets 9 score
# 2020-10-06 16:29:24.726131: User [  alyssa  ] gets 7 score
# 2020-10-06 16:29:25.022291: User [  alyssa  ] gets 8 score
# 2020-10-06 16:29:25.569045: User [   reed   ] gets 3 score
# 2020-10-06 16:29:25.806685: User [  wesley  ] gets 0 score
# 2020-10-06 16:29:25.825025: User [  mariam  ] gets 7 score
# 2020-10-06 16:29:26.131337: User [  teegan  ] gets 7 score
# 2020-10-06 16:29:26.193577: User [  mariam  ] gets 5 score
# 2020-10-06 16:29:26.355174: User [  quynn   ] gets 9 score
# 2020-10-06 16:29:26.765442: User [  maggy   ] gets 3 score
# 2020-10-06 16:29:27.035750: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:27.429912: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:27.524840: User [  mariam  ] gets 9 score
# 2020-10-06 16:29:27.594330: User [  mariam  ] gets 7 score
# 2020-10-06 16:29:27.685528: User [ macaulay ] gets 3 score
# 2020-10-06 16:29:27.886866: User [  marah   ] gets 3 score
# 2020-10-06 16:29:28.970994: User [  teegan  ] gets 9 score
# 2020-10-06 16:29:29.169898: User [  kuame   ] gets 7 score
# 2020-10-06 16:29:29.181054: User [  maggy   ] gets 6 score
# 2020-10-06 16:29:29.183195: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:29.280815: User [  kuame   ] gets 2 score
# 2020-10-06 16:29:29.736623: User [  marah   ] gets 0 score
# 2020-10-06 16:29:29.763216: User [  alyssa  ] gets 5 score
# 2020-10-06 16:29:29.876620: User [  quynn   ] gets 5 score
# 2020-10-06 16:29:30.016448: User [  wesley  ] gets 0 score
# 2020-10-06 16:29:30.234480: User [   reed   ] gets 6 score
# 2020-10-06 16:29:30.594449: User [  mariam  ] gets 6 score
# 2020-10-06 16:29:31.298541: User [  mariam  ] gets 9 score
# 2020-10-06 16:29:31.504997: User [  teegan  ] gets 8 score
# 2020-10-06 16:29:31.877334: User [  quynn   ] gets 2 score
# 2020-10-06 16:29:32.320642: User [  kuame   ] gets 4 score
# 2020-10-06 16:29:32.329062: User [  alyssa  ] gets 0 score
# 2020-10-06 16:29:32.362548: User [  quynn   ] gets 8 score
# 2020-10-06 16:29:32.823711: User [ macaulay ] gets 4 score
# 2020-10-06 16:29:32.884715: User [  quynn   ] gets 7 score
# 2020-10-06 16:29:33.192180: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:33.204060: User [  quynn   ] gets 2 score
# 2020-10-06 16:29:33.462597: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:33.811036: User [  quynn   ] gets 5 score
# 2020-10-06 16:29:34.185625: User [  wesley  ] gets 0 score
# 2020-10-06 16:29:34.201561: User [   reed   ] gets 1 score
# 2020-10-06 16:29:34.544257: User [  wesley  ] gets 6 score
# 2020-10-06 16:29:34.672541: User [  marah   ] gets 6 score
# 2020-10-06 16:29:35.349254: User [ macaulay ] gets 3 score
# 2020-10-06 16:29:35.386522: User [  maggy   ] gets 3 score
# 2020-10-06 16:29:35.840190: User [  mariam  ] gets 2 score
# 2020-10-06 16:29:36.197045: User [  teegan  ] gets 6 score
# 2020-10-06 16:29:36.927934: User [  alyssa  ] gets 8 score
# 2020-10-06 16:29:37.114629: User [  kuame   ] gets 7 score
# 2020-10-06 16:29:37.476313: User [  maggy   ] gets 3 score
# 2020-10-06 16:29:37.921003: User [  teegan  ] gets 4 score
# 2020-10-06 16:29:37.986120: User [  quynn   ] gets 2 score
# 2020-10-06 16:29:38.174246: User [  wesley  ] gets 9 score
# 2020-10-06 16:29:38.406802: User [  alyssa  ] gets 3 score
# 2020-10-06 16:29:38.469404: User [   reed   ] gets 8 score
# 2020-10-06 16:29:38.697031: User [  maggy   ] gets 3 score
# 2020-10-06 16:29:38.902087: User [  marah   ] gets 6 score
# 2020-10-06 16:29:38.909032: User [ macaulay ] gets 4 score
# 2020-10-06 16:29:39.200599: User [  marah   ] gets 2 score
# 2020-10-06 16:29:39.668362: User [  teegan  ] gets 8 score
# 2020-10-06 16:29:39.835379: User [  mariam  ] gets 8 score
# 2020-10-06 16:29:39.900079: User [   reed   ] gets 2 score
# 2020-10-06 16:29:40.040956: User [  quynn   ] gets 9 score
# 2020-10-06 16:29:40.578358: User [  marah   ] gets 3 score
# 2020-10-06 16:29:40.791616: User [  wesley  ] gets 6 score
# 2020-10-06 16:29:40.925967: User [ macaulay ] gets 6 score
# 2020-10-06 16:29:41.044549: User [  kuame   ] gets 1 score
# 2020-10-06 16:29:41.190412: User [ macaulay ] gets 7 score
# 2020-10-06 16:29:42.189666: User [  mariam  ] gets 5 score
# 2020-10-06 16:29:42.381738: User [  kuame   ] gets 2 score
# 2020-10-06 16:29:42.455836: User [  alyssa  ] gets 1 score
# 2020-10-06 16:29:42.500830: User [   reed   ] gets 7 score
# 2020-10-06 16:29:42.637757: User [  marah   ] gets 0 score
# 2020-10-06 16:29:42.940222: User [  alyssa  ] gets 8 score
# 2020-10-06 16:29:43.096262: User [  maggy   ] gets 1 score
# 2020-10-06 16:29:43.597124: User [ macaulay ] gets 5 score
# 2020-10-06 16:29:44.361226: User [  teegan  ] gets 0 score
# 2020-10-06 16:29:44.600283: User [  quynn   ] gets 6 score
# 2020-10-06 16:29:44.709233: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:44.709211: User [  wesley  ] gets 0 score
# 2020-10-06 16:29:45.579487: User [  marah   ] gets 5 score
# 2020-10-06 16:29:46.157763: User [ macaulay ] gets 3 score
# 2020-10-06 16:29:46.348018: User [   reed   ] gets 9 score
# 2020-10-06 16:29:46.650936: User [  alyssa  ] gets 6 score
# 2020-10-06 16:29:46.748711: User [  mariam  ] gets 7 score
# 2020-10-06 16:29:46.821318: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:46.975238: User [ macaulay ] gets 9 score
# 2020-10-06 16:29:47.631648: User [  marah   ] gets 6 score
# 2020-10-06 16:29:47.773849: User [  maggy   ] gets 9 score
# 2020-10-06 16:29:48.194385: User [   reed   ] gets 6 score
# 2020-10-06 16:29:48.295660: User [  marah   ] gets 6 score
# 2020-10-06 16:29:48.457796: User [  alyssa  ] gets 4 score
# 2020-10-06 16:29:48.632872: User [  teegan  ] gets 9 score
# 2020-10-06 16:29:48.972548: User [  teegan  ] gets 0 score
# 2020-10-06 16:29:49.269134: User [  quynn   ] gets 3 score
# 2020-10-06 16:29:49.359159: User [  wesley  ] gets 4 score
# 2020-10-06 16:29:49.670071: User [  marah   ] gets 1 score
# 2020-10-06 16:29:50.111841: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:50.446607: User [  alyssa  ] gets 4 score
# 2020-10-06 16:29:50.579060: User [  wesley  ] gets 2 score
# 2020-10-06 16:29:50.633173: User [  maggy   ] gets 0 score
# 2020-10-06 16:29:50.896569: User [ macaulay ] gets 5 score
# 2020-10-06 16:29:50.897074: User [  teegan  ] gets 3 score
# 2020-10-06 16:29:50.909055: User [  mariam  ] gets 1 score
# 2020-10-06 16:29:51.310091: User [   reed   ] gets 1 score
# 2020-10-06 16:29:51.372498: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:51.675584: User [  mariam  ] gets 0 score
# 2020-10-06 16:29:52.058457: User [  quynn   ] gets 9 score
# 2020-10-06 16:29:52.522155: User [  marah   ] gets 6 score
# 2020-10-06 16:29:52.610529: User [   reed   ] gets 3 score
# 2020-10-06 16:29:52.673971: User [  marah   ] gets 7 score
# 2020-10-06 16:29:52.960021: User [  marah   ] gets 2 score
# 2020-10-06 16:29:52.971418: User [ macaulay ] gets 1 score
# 2020-10-06 16:29:53.175748: User [  maggy   ] gets 2 score
# 2020-10-06 16:29:53.228405: User [  mariam  ] gets 2 score
# 2020-10-06 16:29:53.556150: User [  wesley  ] gets 8 score
# 2020-10-06 16:29:54.203929: User [  alyssa  ] gets 2 score
# 2020-10-06 16:29:54.206931: User [  marah   ] gets 9 score
# 2020-10-06 16:29:54.218675: User [ macaulay ] gets 8 score
# 2020-10-06 16:29:54.485959: User [  wesley  ] gets 9 score
# 2020-10-06 16:29:55.073003: User [  quynn   ] gets 3 score
# 2020-10-06 16:29:55.120404: User [   reed   ] gets 9 score
# 2020-10-06 16:29:55.231659: User [  kuame   ] gets 8 score
# 2020-10-06 16:29:55.518051: User [  teegan  ] gets 5 score
# 2020-10-06 16:29:56.171585: User [   reed   ] gets 7 score
# 2020-10-06 16:29:56.754587: User [  alyssa  ] gets 0 score
# 2020-10-06 16:29:56.883783: User [   reed   ] gets 8 score
# 2020-10-06 16:29:57.273992: User [ macaulay ] gets 4 score
# 2020-10-06 16:29:57.461875: User [  mariam  ] gets 1 score
# 2020-10-06 16:29:57.582732: User [  quynn   ] gets 5 score
# 2020-10-06 16:29:57.669804: User [  maggy   ] gets 7 score
# 2020-10-06 16:29:58.058905: User [  wesley  ] gets 4 score
# 2020-10-06 16:29:58.441495: User [  alyssa  ] gets 2 score
# 2020-10-06 16:29:58.837993: User [  wesley  ] gets 6 score
# 2020-10-06 16:29:59.054561: User [  kuame   ] gets 3 score
# 2020-10-06 16:29:59.184563: User [  marah   ] gets 8 score
# 2020-10-06 16:30:00.042105: User [  teegan  ] gets 4 score
# 2020-10-06 16:30:00.116162: User [  maggy   ] gets 0 score
# 2020-10-06 16:30:00.155317: User [  mariam  ] gets 9 score
# 2020-10-06 16:30:00.327988: User [  wesley  ] gets 3 score
# 2020-10-06 16:30:00.709105: User [  quynn   ] gets 8 score
# 2020-10-06 16:30:00.761732: User [  mariam  ] gets 8 score
# 2020-10-06 16:30:00.852236: User [  alyssa  ] gets 6 score
# 2020-10-06 16:30:01.014449: User [   reed   ] gets 3 score
# 2020-10-06 16:30:01.165381: User [  teegan  ] gets 6 score
# 2020-10-06 16:30:01.203245: User [  alyssa  ] gets 1 score
# 2020-10-06 16:30:01.471664: User [  kuame   ] gets 6 score
# 2020-10-06 16:30:01.572132: User [  mariam  ] gets 3 score
# 2020-10-06 16:30:01.927417: User [ macaulay ] gets 3 score
# 2020-10-06 16:30:02.039606: User [  teegan  ] gets 6 score
# 2020-10-06 16:30:02.195507: User [  alyssa  ] gets 3 score
# 2020-10-06 16:30:03.159965: User [  mariam  ] gets 0 score
# 2020-10-06 16:30:03.804610: User [  quynn   ] gets 5 score
# 2020-10-06 16:30:03.879389: User [  marah   ] gets 1 score
# 2020-10-06 16:30:04.247926: User [  wesley  ] gets 4 score

# %%
# check the data in Leaderboard table is correct
for user_id, items in user_scores.items():
    python_score = sum([item['Score'] for item in items])
    dynamodb_score = int(leaderboard.get_item(Key={'UserId': user_id})['Item']['Score'])
    
    print('User [{:^10}] Score: Python ({}), DynamoDB ({})'.format(user_id, python_score, dynamodb_score))
# Out:
# User [   reed   ] Score: Python (101), DynamoDB (101)
# User [  maggy   ] Score: Python (93), DynamoDB (93)
# User [ macaulay ] Score: Python (99), DynamoDB (99)
# User [  kuame   ] Score: Python (102), DynamoDB (102)
# User [  mariam  ] Score: Python (125), DynamoDB (125)
# User [  quynn   ] Score: Python (129), DynamoDB (129)
# User [  teegan  ] Score: Python (104), DynamoDB (104)
# User [  marah   ] Score: Python (114), DynamoDB (114)
# User [  alyssa  ] Score: Python (97), DynamoDB (97)
# User [  wesley  ] Score: Python (103), DynamoDB (103)

# %% [markdown]
# Finally we're done! We can satisfy the query patterns mentioned in the beginning as follows.

# %%
# Return user's score history up to 10 items sorted timestamp descending
response = user_score_events.query(
    KeyConditionExpression=Key('UserId').eq('alyssa'),
    ScanIndexForward=False,
    Limit=10
)

pprint(response)
# Out:
# {'Count': 10,
#  'Items': [{'Score': Decimal('3'),
#             'Timestamp': '2020-10-06 16:30:02.195507',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('1'),
#             'Timestamp': '2020-10-06 16:30:01.203245',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('6'),
#             'Timestamp': '2020-10-06 16:30:00.852236',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('2'),
#             'Timestamp': '2020-10-06 16:29:58.441495',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('0'),
#             'Timestamp': '2020-10-06 16:29:56.754587',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('2'),
#             'Timestamp': '2020-10-06 16:29:54.203929',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('4'),
#             'Timestamp': '2020-10-06 16:29:50.446607',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('4'),
#             'Timestamp': '2020-10-06 16:29:48.457796',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('6'),
#             'Timestamp': '2020-10-06 16:29:46.650936',
#             'UserId': 'alyssa'},
#            {'Score': Decimal('8'),
#             'Timestamp': '2020-10-06 16:29:42.940222',
#             'UserId': 'alyssa'}],
#  'LastEvaluatedKey': {'Timestamp': '2020-10-06 16:29:42.940222',
#                       'UserId': 'alyssa'},
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '1042',
#                                       'content-type': 'application/x-amz-json-1.0',
#                                       'date': 'Tue, 06 Oct 2020 16:35:09 GMT',
#                                       'server': 'Server',
#                                       'x-amz-crc32': '3137563235',
#                                       'x-amzn-requestid': '19RRBL646FERLAODJO2A00LMB7VV4KQNSO5AEMVJF66Q9ASUAAJG'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '19RRBL646FERLAODJO2A00LMB7VV4KQNSO5AEMVJF66Q9ASUAAJG',
#                       'RetryAttempts': 0},
#  'ScannedCount': 10}

# %%
# Return the latest user total score from 1st to 5rd ordered by score descending
responses = []

for shard_no in range(10):
    response = leaderboard.query(
        IndexName='IndexShardNoScore',
        KeyConditionExpression=Key('ShardNo').eq(shard_no),
        ScanIndexForward=False,
        Limit=5
    )
    if response['Items']:
        for item in response['Items']:
            responses.append({
                'score': int(item['Score']),
                'user_id': item['UserId']
            })

heapq.nlargest(5, responses, key=lambda item: item['score'])
# Out:
# [{'score': 129, 'user_id': 'quynn'},
#  {'score': 125, 'user_id': 'mariam'},
#  {'score': 114, 'user_id': 'marah'},
#  {'score': 104, 'user_id': 'teegan'},
#  {'score': 103, 'user_id': 'wesley'}]
